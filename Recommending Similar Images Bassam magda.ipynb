# %% [markdown]
# This notebook represents a prototypical python 3 implementation for a without safeguards, without asserts, with fixed paramterized model. For larger data sets it is advised to store intermediate results, e.g. as pickle files.
#
# Theory https://towardsdatascience.com/effortlessly-recommending-similar-images-b65aff6aabfb
#
#
#
# # Rescaling
#
# We assume to have a folder "originalImages" in the working directory. It shall contain jpg images.
# As we will employ resnet18 using PyTorch, we need to resize the images to normalized 224x224 images
# In a first step they are resized and stored in a different folder inputImagesCNN

# %%
import os
import cv2
from PIL import Image
from torchvision import transforms

inputPNG = "VINCENT_PNG"
inputDir = "VINCENT"

for imageName in os.listdir(inputPNG):
    image =cv2.imread(os.path.join(inputPNG, imageName), 1)
    cv2.imwrite(os.path.join(inputDir, imageName[:-3]+'jpg'), image)

# %%
# needed input dimensions for the CNN
inputDim = (224,224)

inputDirCNN =  "VINCENT_CNN"

os.makedirs(inputDirCNN, exist_ok = True)

transformationForCNNInput = transforms.Compose([transforms.Resize(inputDim)])

for imageName in os.listdir(inputDir):
    I = Image.open(os.path.join(inputDir, imageName))
    newI = transformationForCNNInput(I)

    # copy the rotation information metadata from original image and save, else your transformed images may be rotated
    #exif = I.info['exif']
    newI.save(os.path.join(inputDirCNN, imageName))
    
    newI.close()
    I.close()

# %% [markdown]
# # Creating the similarity matrix with Resnet18
#
# Let us first calculate the feature vectors with resnet18 on a CPU. The input is normalized to the ImageNet mean values/standard deviation.

# %%
import torch
from tqdm import tqdm
from torchvision import models

# for this prototype we use no gpu, cuda= False and as model resnet18 to obtain feature vectors

class Img2VecResnet18():
    def __init__(self):
        
        self.device = torch.device("cpu")
        self.numberFeatures = 512
        self.modelName = "resnet-18"
        self.model, self.featureLayer = self.getFeatureLayer()
        self.model = self.model.to(self.device)
        self.model.eval()
        self.toTensor = transforms.ToTensor()
        
        # normalize the resized images as expected by resnet18
        # [0.485, 0.456, 0.406] --> normalized mean value of ImageNet, [0.229, 0.224, 0.225] std of ImageNet
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        
    def getVec(self, img):
        image = self.normalize(self.toTensor(img)).unsqueeze(0).to(self.device)
        embedding = torch.zeros(1, self.numberFeatures, 1, 1)

        def copyData(m, i, o): embedding.copy_(o.data)

        h = self.featureLayer.register_forward_hook(copyData)
        self.model(image)
        h.remove()

        return embedding.numpy()[0, :, 0, 0]

    def getFeatureLayer(self):
        
        cnnModel = models.resnet18(pretrained=True)
        layer = cnnModel._modules.get('avgpool')
        self.layer_output_size = 512
        
        return cnnModel, layer
        

# generate vectors for all the images in the set
img2vec = Img2VecResnet18() 

allVectors = {}
print("Converting images to feature vectors:")
for image in tqdm(os.listdir("VINCENT_CNN")):
    I = Image.open(os.path.join("VINCENT_CNN", image))
    vec = img2vec.getVec(I)
    allVectors[image] = vec
    I.close()
# Out:
# Converting images to feature vectors:
# 100%|██████████| 11/11 [00:00<00:00, 18.09it/s]

# %% [markdown]
# # Cosine similarity
# Calculate for all vectors the cosine similarity to the other vectors.
# Note that this matrix may become huge, hence infefficient, with many thousands of images

# %%
# now let us define a function that calculates the cosine similarity entries in the similarity matrix
import pandas as pd
import numpy as np

def getSimilarityMatrix(vectors):
    v = np.array(list(vectors.values())).T
    sim = np.inner(v.T, v.T) / ((np.linalg.norm(v, axis=0).reshape(-1,1)) * ((np.linalg.norm(v, axis=0).reshape(-1,1)).T))
    keys = list(vectors.keys())
    matrix = pd.DataFrame(sim, columns = keys, index = keys)
    
    return matrix
        
similarityMatrix = getSimilarityMatrix(allVectors)
print(similarityMatrix)
# Out:
#                            VINCENT_photo_1_image.jpg  \
# VINCENT_photo_1_image.jpg                   1.000000
# VINCENT_photo_2_image.jpg                   0.554432
# VINCENT_photo_3_image.jpg                   0.625345
# VINCENT_photo_4_image.jpg                   0.565020
# VINCENT_photo_5_image.jpg                   0.570820
# VINCENT_photo_6_image.jpg                   0.568087
# VINCENT_photo_7_image.jpg                   0.715198
# VINCENT_photo_8_image.jpg                   0.659904
# VINCENT_selfie1.png.jpg                     0.511329
# VINCENT_selfie2.jpg                         0.518261
# VINCENT_selfie2.png.jpg                     0.518261
#
#                            VINCENT_photo_2_image.jpg  \
# VINCENT_photo_1_image.jpg                   0.554432
# VINCENT_photo_2_image.jpg                   1.000000
# VINCENT_photo_3_image.jpg                   0.615568
# VINCENT_photo_4_image.jpg                   0.515687
# VINCENT_photo_5_image.jpg                   0.533139
# VINCENT_photo_6_image.jpg                   0.531840
# VINCENT_photo_7_image.jpg                   0.550495
# VINCENT_photo_8_image.jpg                   0.589957
# VINCENT_selfie1.png.jpg                     0.618833
# VINCENT_selfie2.jpg                         0.589160
# VINCENT_selfie2.png.jpg                     0.589160
#
#                            VINCENT_photo_3_image.jpg  \
# VINCENT_photo_1_image.jpg                   0.625345
# VINCENT_photo_2_image.jpg                   0.615568
# VINCENT_photo_3_image.jpg                   1.000000
# VINCENT_photo_4_image.jpg                   0.513214
# VINCENT_photo_5_image.jpg                   0.582616
# VINCENT_photo_6_image.jpg                   0.520254
# VINCENT_photo_7_image.jpg                   0.637291
# VINCENT_photo_8_image.jpg                   0.691009
# VINCENT_selfie1.png.jpg                     0.658623
# VINCENT_selfie2.jpg                         0.658867
# VINCENT_selfie2.png.jpg                     0.658867
#
#                            VINCENT_photo_4_image.jpg  \
# VINCENT_photo_1_image.jpg                   0.565020
# VINCENT_photo_2_image.jpg                   0.515687
# VINCENT_photo_3_image.jpg                   0.513214
# VINCENT_photo_4_image.jpg                   1.000000
# VINCENT_photo_5_image.jpg                   0.606306
# VINCENT_photo_6_image.jpg                   0.704385
# VINCENT_photo_7_image.jpg                   0.609227
# VINCENT_photo_8_image.jpg                   0.660469
# VINCENT_selfie1.png.jpg                     0.459798
# VINCENT_selfie2.jpg                         0.485820
# VINCENT_selfie2.png.jpg                     0.485820
#
#                            VINCENT_photo_5_image.jpg  \
# VINCENT_photo_1_image.jpg                   0.570820
# VINCENT_photo_2_image.jpg                   0.533139
# VINCENT_photo_3_image.jpg                   0.582616
# VINCENT_photo_4_image.jpg                   0.606306
# VINCENT_photo_5_image.jpg                   1.000000
# VINCENT_photo_6_image.jpg                   0.687494
# VINCENT_photo_7_image.jpg                   0.689766
# VINCENT_photo_8_image.jpg                   0.723334
# VINCENT_selfie1.png.jpg                     0.518609
# VINCENT_selfie2.jpg                         0.525348
# VINCENT_selfie2.png.jpg                     0.525348
#
#                            VINCENT_photo_6_image.jpg  \
# VINCENT_photo_1_image.jpg                   0.568087
# VINCENT_photo_2_image.jpg                   0.531840
# VINCENT_photo_3_image.jpg                   0.520254
# VINCENT_photo_4_image.jpg                   0.704385
# VINCENT_photo_5_image.jpg                   0.687494
# VINCENT_photo_6_image.jpg                   1.000000
# VINCENT_photo_7_image.jpg                   0.690685
# VINCENT_photo_8_image.jpg                   0.699244
# VINCENT_selfie1.png.jpg                     0.445487
# VINCENT_selfie2.jpg                         0.471809
# VINCENT_selfie2.png.jpg                     0.471809
#
#                            VINCENT_photo_7_image.jpg  \
# VINCENT_photo_1_image.jpg                   0.715198
# VINCENT_photo_2_image.jpg                   0.550495
# VINCENT_photo_3_image.jpg                   0.637291
# VINCENT_photo_4_image.jpg                   0.609227
# VINCENT_photo_5_image.jpg                   0.689766
# VINCENT_photo_6_image.jpg                   0.690685
# VINCENT_photo_7_image.jpg                   1.000000
# VINCENT_photo_8_image.jpg                   0.778133
# VINCENT_selfie1.png.jpg                     0.540310
# VINCENT_selfie2.jpg                         0.544696
# VINCENT_selfie2.png.jpg                     0.544696
#
#                            VINCENT_photo_8_image.jpg  VINCENT_selfie1.png.jpg  \
# VINCENT_photo_1_image.jpg                   0.659904                 0.511329
# VINCENT_photo_2_image.jpg                   0.589957                 0.618833
# VINCENT_photo_3_image.jpg                   0.691009                 0.658623
# VINCENT_photo_4_image.jpg                   0.660469                 0.459798
# VINCENT_photo_5_image.jpg                   0.723334                 0.518609
# VINCENT_photo_6_image.jpg                   0.699244                 0.445487
# VINCENT_photo_7_image.jpg                   0.778133                 0.540310
# VINCENT_photo_8_image.jpg                   1.000000                 0.543377
# VINCENT_selfie1.png.jpg                     0.543377                 1.000000
# VINCENT_selfie2.jpg                         0.575862                 0.802316
# VINCENT_selfie2.png.jpg                     0.575863                 0.802316
#
#                            VINCENT_selfie2.jpg  VINCENT_selfie2.png.jpg
# VINCENT_photo_1_image.jpg             0.518261                 0.518261
# VINCENT_photo_2_image.jpg             0.589160                 0.589160
# VINCENT_photo_3_image.jpg             0.658867                 0.658867
# VINCENT_photo_4_image.jpg             0.485820                 0.485820
# VINCENT_photo_5_image.jpg             0.525348                 0.525348
# VINCENT_photo_6_image.jpg             0.471809                 0.471809
# VINCENT_photo_7_image.jpg             0.544696                 0.544696
# VINCENT_photo_8_image.jpg             0.575862                 0.575863
# VINCENT_selfie1.png.jpg               0.802316                 0.802316
# VINCENT_selfie2.jpg                   1.000000                 1.000000
# VINCENT_selfie2.png.jpg               1.000000                 1.000000

# %% [markdown]
# # Prepare top-k lists
# Now that the similarity matrix is fully available, the last step is to sort the values per item and store the top similar entries in another data structure

# %%
from numpy.testing import assert_almost_equal
import pickle

k = 5 # the number of top similar images to be stored

similarNames = pd.DataFrame(index = similarityMatrix.index, columns = range(k))
similarValues = pd.DataFrame(index = similarityMatrix.index, columns = range(k))

for j in tqdm(range(similarityMatrix.shape[0])):
    kSimilar = similarityMatrix.iloc[j, :].sort_values(ascending = False).head(k)
    similarNames.iloc[j, :] = list(kSimilar.index)
    similarValues.iloc[j, :] = kSimilar.values
    
similarNames.to_pickle("similarNames.pkl")
similarValues.to_pickle("similarValues.pkl")
# Out:
# 100%|██████████| 11/11 [00:00<00:00, 1514.79it/s]

# %% [markdown]
# # Get and visualize similar images for four example inputs

# %%
import matplotlib.pyplot as plt
    
# take three examples from the provided image set and plot
inputImages = ["VINCENT_photo_1_image.jpg", "VINCENT_photo_6_image.jpg"]

numCol = 5
numRow = 1

def setAxes(ax, image, query = False, **kwargs):
    value = kwargs.get("value", None)
    if query:
        ax.set_xlabel("Query Image\n{0}".format(image), fontsize = 12)
    else:
        ax.set_xlabel("Similarity value {1:1.3f}\n{0}".format( image,  value), fontsize = 12)
    ax.set_xticks([])
    ax.set_yticks([])
    
def getSimilarImages(image, simNames, simVals):
    if image in set(simNames.index):
        imgs = list(simNames.loc[image, :])
        vals = list(simVals.loc[image, :])
        if image in imgs:
            assert_almost_equal(max(vals), 1, decimal = 5)
            imgs.remove(image)
            vals.remove(max(vals))
        return imgs, vals
    else:
        print("'{}' Unknown image".format(image))
        
def plotSimilarImages(image, simiarNames, similarValues):
    simImages, simValues = getSimilarImages(image, similarNames, similarValues)
    fig = plt.figure(figsize=(10, 20))
    
    # now plot the  most simliar images
    for j in range(0, numCol*numRow):
        ax = []
        if j == 0:
            img = Image.open(os.path.join(inputDir, image))
            ax = fig.add_subplot(numRow, numCol, 1)
            setAxes(ax, image, query = True)
        else:
            img = Image.open(os.path.join(inputDir, simImages[j-1]))
            ax.append(fig.add_subplot(numRow, numCol, j+1))
            setAxes(ax[-1], simImages[j-1], value = simValues[j-1])
        img = img.convert('RGB')
        plt.imshow(img)
        img.close()
    
    plt.show()
        
for image in inputImages:
    plotSimilarImages(image, similarNames, similarValues)
